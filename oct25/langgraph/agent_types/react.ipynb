# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os
from langchain_core.language_models.chat_models import BaseChatModel
def get_llm() -> BaseChatModel:
    load_dotenv()
    model_name = os.getenv('MODEL_NAME')
    model_provider = os.getenv('MODEL_PROVIDER')
    llm = init_chat_model(model=model_name, model_provider=model_provider)
    return llm

# %%
llm = get_llm()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llm = get_llm()
#
# Cell In[5], line 9, in get_llm()
#       7 model_name = os.getenv('MODEL_NAME')
#       8 model_provider = os.getenv('MODEL_PROVIDER')
# ----> 9 llm = init_chat_model(model=model_name, model_provider=model_provider)
#      10 return llm
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\langchain\chat_models\base.py:314, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     306     warnings.warn(
#     307         f"{config_prefix=} has been set but no fields are configurable. Set "
#     308         f"`configurable_fields=(...)` to specify the model params that are "
#     309         f"configurable.",
#     310         stacklevel=2,
#     311     )
#     313 if not configurable_fields:
# --> 314     return _init_chat_model_helper(
#     315         cast("str", model),
#     316         model_provider=model_provider,
#     317         **kwargs,
#     318     )
#     319 if model:
#     320     kwargs["model"] = model
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\langchain\chat_models\base.py:364, in _init_chat_model_helper(model, model_provider, **kwargs)
#     362 if model_provider == "google_vertexai":
#     363     _check_pkg("langchain_google_vertexai")
# --> 364     from langchain_google_vertexai import ChatVertexAI
#     366     return ChatVertexAI(model=model, **kwargs)
#     367 if model_provider == "google_genai":
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\langchain_google_vertexai\__init__.py:48
#       1 """LangChain Google Generative AI integration (VertexAI).
#       2
#       3 This module contains the LangChain integrations for
#    (...)     37 credentials variable mentioned above, and then looks for system-level auth.
#      38 """
#      40 from google.cloud.aiplatform_v1beta1.types import (
#      41     FunctionCallingConfig,
#      42     FunctionDeclaration,
#    (...)     45     Type,
#      46 )
# ---> 48 from langchain_google_vertexai._enums import (
#      49     HarmBlockThreshold,
#      50     HarmCategory,
#      51     Modality,
#      52     SafetySetting,
#      53 )
#      54 from langchain_google_vertexai.chains import create_structured_runnable
#      55 from langchain_google_vertexai.chat_models import ChatVertexAI
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\langchain_google_vertexai\_enums.py:2
#       1 from google.cloud.aiplatform_v1beta1.types.content import Modality
# ----> 2 from vertexai.generative_models import (
#       3     HarmBlockThreshold,  # TODO: migrate to google-genai since this is deprecated
#       4     HarmCategory,
#       5     SafetySetting,
#       6 )
#       8 __all__ = ["HarmBlockThreshold", "HarmCategory", "Modality", "SafetySetting"]
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\vertexai\__init__.py:20
#      17 import importlib
#      18 import sys
# ---> 20 from google.cloud.aiplatform import version as aiplatform_version
#      22 __version__ = aiplatform_version.__version__
#      24 from google.cloud.aiplatform import init
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform\__init__.py:24
#      19 from google.cloud.aiplatform import version as aiplatform_version
#      21 __version__ = aiplatform_version.__version__
# ---> 24 from google.cloud.aiplatform import initializer
#      26 from google.cloud.aiplatform.datasets import (
#      27     ImageDataset,
#      28     TabularDataset,
#    (...)     31     VideoDataset,
#      32 )
#      33 from google.cloud.aiplatform import explain
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:35
#      32 from google.auth.exceptions import GoogleAuthError
#      34 from google.cloud.aiplatform import __version__
# ---> 35 from google.cloud.aiplatform import compat
#      36 from google.cloud.aiplatform.constants import base as constants
#      37 from google.cloud.aiplatform import utils
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform\compat\__init__.py:18
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright 2023 Google LLC
#    (...)     15 # limitations under the License.
#      16 #
# ---> 18 from google.cloud.aiplatform.compat import services
#      19 from google.cloud.aiplatform.compat import types
#      21 V1BETA1 = "v1beta1"
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform\compat\services\__init__.py:191
#     185 from google.cloud.aiplatform_v1.services.schedule_service import (
#     186     client as schedule_service_client_v1,
#     187 )
#     188 from google.cloud.aiplatform_v1.services.specialist_pool_service import (
#     189     client as specialist_pool_service_client_v1,
#     190 )
# --> 191 from google.cloud.aiplatform_v1.services.tensorboard_service import (
#     192     client as tensorboard_service_client_v1,
#     193 )
#     194 from google.cloud.aiplatform_v1.services.vizier_service import (
#     195     client as vizier_service_client_v1,
#     196 )
#     197 from google.cloud.aiplatform_v1.services.vertex_rag_service import (
#     198     client as vertex_rag_service_client_v1,
#     199 )
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform_v1\services\tensorboard_service\__init__.py:16
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2025 Google LLC
#       3 #
#    (...)     14 # limitations under the License.
#      15 #
# ---> 16 from .client import TensorboardServiceClient
#      17 from .async_client import TensorboardServiceAsyncClient
#      19 __all__ = (
#      20     "TensorboardServiceClient",
#      21     "TensorboardServiceAsyncClient",
#      22 )
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform_v1\services\tensorboard_service\client.py:38
#      22 from typing import (
#      23     Dict,
#      24     Callable,
#    (...)     34     cast,
#      35 )
#      36 import warnings
# ---> 38 from google.cloud.aiplatform_v1 import gapic_version as package_version
#      40 from google.api_core import client_options as client_options_lib
#      41 from google.api_core import exceptions as core_exceptions
#
# File c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform_v1\__init__.py:95
#      93 from .services.specialist_pool_service import SpecialistPoolServiceClient
#      94 from .services.specialist_pool_service import SpecialistPoolServiceAsyncClient
# ---> 95 from .services.tensorboard_service import TensorboardServiceClient
#      96 from .services.tensorboard_service import TensorboardServiceAsyncClient
#      97 from .services.vertex_rag_data_service import VertexRagDataServiceClient
#
# ImportError: cannot import name 'TensorboardServiceClient' from partially initialized module 'google.cloud.aiplatform_v1.services.tensorboard_service' (most likely due to a circular import) (c:\khajaclassroom\GenerativeAI\agenticai\oct25\langgraph\agent_types\.venv\Lib\site-packages\google\cloud\aiplatform_v1\services\tensorboard_service\__init__.py)

# %%
from langgraph.prebuilt import create_react_agent
