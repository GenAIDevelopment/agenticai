# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
project = os.getenv('GOOGLE_CLOUD_PROJECT')


# model
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash-lite",
    vertexai = True,
    project = project
)

# %%
# Prompt Template
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["country"],
    template="What is capital of the {country}"
)

# %%
template.format(country = "India")
# Out:
# 'What is capital of the India'

# %%
## Langchain
chain = template | llm 
response = chain.invoke({'country': 'India'})

# %%
response.content
# Out:
# 'The capital of India is **New Delhi**.'

# %%
template = PromptTemplate(
    input_variables=["country", "topic"],
    template="Explain about {topic} with respect to {country}"
)

# %%
chain = template | llm
response = chain.invoke({"country": "India", "topic": "Independence"})
response.content
# Out:
# "## Independence with Respect to India: A Journey from Colonial Rule to Self-Determination\n\nIndependence for India, achieved on **August 15, 1947**, signifies the end of nearly 200 years of British colonial rule and the dawn of a new era of self-governance. It's a multifaceted concept that encompasses not just political freedom but also social, economic, and cultural liberation.\n\nHere's a breakdown of independence with respect to India:\n\n**1. Political Independence: The Core of the Struggle**\n\n* **Freedom from Foreign Domination:** The most fundamental aspect of Indian independence is the liberation from the political and administrative control of the British Crown. This meant the cessation of British laws, policies, and governance, and the establishment of an independent Indian government.\n* **Sovereignty and Self-Determination:** India gained the right to govern itself, make its own laws, and chart its own course in international affairs. This marked a shift from being a colony, whose destiny was dictated by a foreign power, to a sovereign nation with the power of self-determination.\n* **Establishment of Democratic Institutions:** The attainment of independence paved the way for the establishment of a democratic republic. This included the drafting of a constitution, the formation of a parliament, and the creation of independent judiciary and executive branches.\n\n**2. The Long and Arduous Struggle:**\n\nIndian independence was not a gift; it was a hard-won victory achieved through decades of struggle involving diverse methods and ideologies:\n\n* **Early Resistance:** The seeds of resistance were sown much earlier, with revolts like the Sepoy Mutiny of 1857 often cited as a significant early uprising against British rule.\n* **Rise of Nationalism:** The late 19th and early 20th centuries witnessed the rise of organized Indian nationalism, fueled by a growing sense of shared identity and a desire for self-rule.\n* **The Indian National Congress (INC):** Founded in 1885, the INC initially sought greater representation within the British system but gradually evolved into a powerful force advocating for complete independence.\n* **Mahatma Gandhi and Non-Violent Civil Disobedience:** Mahatma Gandhi's philosophy of *Satyagraha* (truth force) and *Ahimsa* (non-violence) became the cornerstone of the independence movement. He led mass movements like the Non-Cooperation Movement, the Salt March, and the Quit India Movement, mobilizing millions of Indians to peacefully resist British authority.\n* **Other Nationalist Leaders and Ideologies:** Alongside Gandhi, figures like Jawaharlal Nehru, Sardar Vallabhbhai Patel, Subhas Chandra Bose, Bhagat Singh, and many others played crucial roles, representing different approaches and ideologies within the broader independence movement.\n* **Revolutionary Activities:** While non-violence was dominant, some groups engaged in revolutionary activities, believing armed struggle was necessary to achieve freedom.\n* **Impact of World Wars:** The two World Wars significantly weakened the British Empire and strengthened the resolve of Indian nationalists.\n\n**3. The Price of Independence: Partition**\n\nA significant and tragic consequence of independence was the **Partition of India** in 1947. This led to the creation of two separate nations: India and Pakistan.\n\n* **Religious Divide:** The partition was largely based on religious lines, with the Muslim-majority areas of the subcontinent forming Pakistan.\n* **Mass Migration and Violence:** The partition triggered one of the largest and most violent migrations in human history. Millions of people were displaced, leading to widespread communal riots, bloodshed, and immense suffering.\n* **Lingering Impact:** The wounds of partition continue to affect the relationship between India and Pakistan and have left a lasting scar on the collective memory of the subcontinent.\n\n**4. Post-Independence Challenges and Aspirations:**\n\nAchieving po ...

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ## Independence with Respect to India: A Journey from Colonial Rule to Self-Determination
#
# Independence for India, achieved on **August 15, 1947**, signifies the end of nearly 200 years of British colonial rule and the dawn of a new era of self-governance. It's a multifaceted concept that encompasses not just political freedom but also social, economic, and cultural liberation.
#
# Here's a breakdown of independence with respect to India:
#
# **1. Political Independence: The Core of the Struggle**
#
# * **Freedom from Foreign Domination:** The most fundamental aspect of Indian independence is the liberation from the political and administrative control of the British Crown. This meant the cessation of British laws, policies, and governance, and the establishment of an independent Indian government.
# * **Sovereignty and Self-Determination:** India gained the right to govern itself, make its own laws, and chart its own course in international affairs. This marked a shift from being a colony, whose destiny was dictated by a foreign power, to a sovereign nation with the power of self-determination.
# * **Establishment of Democratic Institutions:** The attainment of independence paved the way for the establishment of a democratic republic. This included the drafting of a constitution, the formation of a parliament, and the creation of independent judiciary and executive branches.
#
# **2. The Long and Arduous Struggle:**
#
# Indian independence was not a gift; it was a hard-won victory achieved through decades of struggle involving diverse methods and ideologies:
#
# * **Early Resistance:** The seeds of resistance were sown much earlier, with revolts like the Sepoy Mutiny of 1857 often cited as a significant early uprising against British rule.
# * **Rise of Nationalism:** The late 19th and early 20th centuries witnessed the rise of organized Indian nationalism, fueled by a growing sense of shared identity and a desire for self-rule.
# * **The Indian National Congress (INC):** Founded in 1885, the INC initially sought greater representation within the British system but gradually evolved into a powerful force advocating for complete independence.
# * **Mahatma Gandhi and Non-Violent Civil Disobedience:** Mahatma Gandhi's philosophy of *Satyagraha* (truth force) and *Ahimsa* (non-violence) became the cornerstone of the independence movement. He led mass movements like the Non-Cooperation Movement, the Salt March, and the Quit India Movement, mobilizing millions of Indians to peacefully resist British authority.
# * **Other Nationalist Leaders and Ideologies:** Alongside Gandhi, figures like Jawaharlal Nehru, Sardar Vallabhbhai Patel, Subhas Chandra Bose, Bhagat Singh, and many others played crucial roles, representing different approaches and ideologies within the broader independence movement.
# * **Revolutionary Activities:** While non-violence was dominant, some groups engaged in revolutionary activities, believing armed struggle was necessary to achieve freedom.
# * **Impact of World Wars:** The two World Wars significantly weakened the British Empire and strengthened the resolve of Indian nationalists.
#
# **3. The Price of Independence: Partition**
#
# A significant and tragic consequence of independence was the **Partition of India** in 1947. This led to the creation of two separate nations: India and Pakistan.
#
# * **Religious Divide:** The partition was largely based on religious lines, with the Muslim-majority areas of the subcontinent forming Pakistan.
# * **Mass Migration and Violence:** The partition triggered one of the largest and most violent migrations in human history. Millions of people were displaced, leading to widespread communal riots, bloodshed, and immense suffering.
# * **Lingering Impact:** The wounds of partition continue to affect the relationship between India and Pakistan and have left a lasting scar on the collective memory of the subcontinent.
#
# **4. Post-Independence Challenges and Aspirations:**
#
# Achieving political independence was only the beginning. India faced numerous challenges in building a new nation:
#
# * **Nation-Building:** Integrating princely states, establishing administrative structures, and fostering national unity were crucial tasks.
# * **Economic Development:** Overcoming poverty, illiteracy, and the legacy of colonial exploitation required significant economic reforms and development initiatives.
# * **Social Justice:** Addressing deep-rooted social inequalities, caste discrimination, and promoting gender equality remained ongoing struggles.
# * **Secularism and Pluralism:** India committed to a secular state, upholding the rights of all religious communities and fostering a pluralistic society.
# * **Foreign Policy:** India adopted a policy of non-alignment during the Cold War, seeking to maintain its independence and promote peace and stability.
#
# **In essence, Indian independence is:**
#
# * **A triumph of the human spirit:** It represents the unwavering determination of a people to break free from oppression and govern themselves.
# * **A testament to diverse forms of struggle:** It highlights the effectiveness of both non-violent resistance and other forms of activism in achieving political goals.
# * **A complex legacy:** While a moment of immense pride and achievement, it is also intertwined with the pain and trauma of partition.
# * **An ongoing journey:** The aspirations for social justice, economic prosperity, and inclusive development continue to shape India's path as an independent nation.
#
# Understanding Indian independence requires appreciating its historical context, the sacrifices made, the complexities of its achievement, and the continuous efforts to realize its full promise for all its citizens.

# %%
# Few shot example
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="You are math teacher for primary school"),
    HumanMessage(content="2 * 2"),
    AIMessage(content="This refers to multiplication \n Ensure you have memorized tables \n  2 * 2 = 4"),
    HumanMessage(content="5 + 5"),
    AIMessage(content="This refers to addition \n Count numbers on fingers \n 5 + 5 = 10"),
    HumanMessage(content="1+4")
]

response = llm.invoke(messages)

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# This refers to addition
# Count numbers on fingers
# 1 + 4 = 5

# %%
# multiple prompts in dynamic
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are math teacher for primary school"),
    ("human", "2 * 2"),
    ("ai", "This refers to multiplication \n Ensure you have memorized tables \n  2 * 2 = 4"),
    ("human", "5 + 5"),
    ("ai", "This refers to addition \n Count numbers on fingers \n 5 + 5 = 10"),
    ("human", "{question}")
])

# %%
chain = prompt | llm
response = chain.invoke({"question": "2 + 4"})
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# This refers to addition
#  Count numbers on fingers
#  2 + 4 = 6

# %%
response = chain.invoke({"question": "2 * 4"})
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# This refers to multiplication.
#  **2 x 4 = 8**

# %%
response = llm.invoke("Hello, My name is khaja")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello Khaja! It's nice to meet you. How can I help you today?

# %%
llm.invoke("What is my name? ").pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# I do not have access to your personal information, including your name. I am a large language model, trained by Google.

# %%
response = llm.invoke("How are you?")

# %%
response.content
# Out:
# 'I am a large language model, trained by Google. I do not have feelings or emotions, so I cannot be "well" or "unwell." However, I am functioning as expected and am ready to assist you.'

# %%
response.content_blocks
# Out:
# [{'type': 'text',
#   'text': 'I am a large language model, trained by Google. I do not have feelings or emotions, so I cannot be "well" or "unwell." However, I am functioning as expected and am ready to assist you.'}]
