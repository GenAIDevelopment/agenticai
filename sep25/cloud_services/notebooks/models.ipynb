# %%
from langchain_google_vertexai import VertexAI

# %%
llm = VertexAI()

# %%
llm.invoke("What is your name ?")
# Out:
# 'I am a large language model, trained by Google.\n'

# %%
from langchain_google_vertexai import ChatVertexAI

chat_llm = ChatVertexAI(model_name="gemini-2.5-flash-lite")
chat_llm.invoke("What is your name ?")
# Out:
# AIMessage(content='I do not have a name. I am a large language model, trained by Google.', additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 5, 'candidates_token_count': 18, 'total_token_count': 23, 'prompt_tokens_details': [{'modality': 1, 'token_count': 5}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 18}], 'thoughts_token_count': 0, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -0.03134347332848443, 'model_name': 'gemini-2.5-flash-lite'}, id='run--64d9a25e-9575-4f93-b5e4-4011b64efdf7-0', usage_metadata={'input_tokens': 5, 'output_tokens': 18, 'total_tokens': 23, 'input_token_details': {'cache_read': 0}})

# %%
# from langchain_google_vertexai import VertexAIModelGarden,

# model_garden_llm = VertexAIModelGarden()

from langchain_google_vertexai.model_garden import ChatAnthropicVertex

llm = ChatAnthropicVertex(
    project="massive-seer-457104-j1",
    location="us-central1",
    model_name="claude-3-haiku@20240307",  # Or other Claude models like 'claude-3-opus@20240229'
    max_tokens=1024  # Optional: Set the maximum number of tokens to generate
)

# %%
llm.invoke("what is capital of france")
# Out:
# Retrying langchain_google_vertexai.model_garden.ChatAnthropicVertex._generate.<locals>._completion_with_retry_inner in 4.0 seconds as it raised NotFoundError: Error code: 404 - {'error': {'code': 404, 'message': 'Publisher Model `projects/massive-seer-457104-j1/locations/us-central1/publishers/anthropic/models/claude-3-haiku@20240307` was not found or your project does not have access to it. Please ensure you are using a valid model version. For more information, see: https://cloud.google.com/vertex-ai/generative-ai/docs/learn/model-versions', 'status': 'NOT_FOUND'}}.
# ...
