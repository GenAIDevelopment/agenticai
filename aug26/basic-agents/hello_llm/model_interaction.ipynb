# %%
# import packages related to loading variables into enviromnet from .env
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
result = llm.invoke("What is capital of France")
result
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIPmVlhm81eEMRxl1Jw88HiPK94tn/PJGgGHcFUev7AAYaCrlpl5aQhZIK33X7IoRrt1wpDnAMUbI2YOZUr9HRVVs57iyczcifb9Uwzs6y78WhkFnrlHSwYD3BRPUojGGELXuGEY8GYcnW9JQ=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0413f-2a36-7363-8262-32aa6b1fc01f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIPmVlhm81eEMRxl1Jw88HiPK94tn/PJGgGHcFUev7AAYaCrlpl5aQhZIK33X7IoRrt1wpDnAMUbI2YOZUr9HRVVs57iyczcifb9Uwzs6y78WhkFnrlHSwYD3BRPUojGGELXuGEY8GYcnW9JQ=='}}]

# %%
result = llm.invoke("What are popular spots in captial of france")
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# ...
