# %%
from langchain.chat_models import init_chat_model, BaseChatModel
from dotenv import load_dotenv

# %%
model_name = 'google_genai:gemini-3.5-flash-lite'
load_dotenv()
# Out:
# True

# %%
model = init_chat_model(
    model_name
)

# %%
from langchain.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "What is capital of {country}")
    ]
)

# %%
model.invoke("What is captial of france?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAERTTIPOa60cDX2L5RgKah+IvXu/jwtL66qQO+B0RR8E86DcbCMA7twtb10GLfHh31bO6iaQq2YdI663xlbyNgPHh5LuWW9Wn8YM8DFfyTYOZOgIh/7demzkVUH'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a08419-45de-7c03-a2a8-7aee05e4577b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 7, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
chain = prompt_template | model

# %%
type(chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %%
chain.invoke({
    'country': 'France'
})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'El4KXAERTTIPcoRcdVL5TOcBfvA+hJJlywttQrpPkZiEabDtrxtDl74BEcC/IPnRI3l/ARhB2U2DzeJFjpiaTDpHava2wQCg4Nud+PmC+h0ySRWjGuoRCMWjtYDbpRoC'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a08426-9d40-7e31-8380-7e864f6a6289-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "What is capital of {country}"),
        ("human", "Explain its significance in {topic}")
    ]
)

# %%
chain = prompt_template | model

# %%
chain.invoke({
    'country': 'India',
    'topic': 'Pollution'
})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of India is **New Delhi** (often simply referred to as Delhi, as New Delhi is the municipal area within the metropolis that serves as the seat of the central government). \n\nBeyond being the political, cultural, and administrative heart of the world’s most populous nation, Delhi is globally infamous for being one of the most polluted capital cities in the world. \n\nHere is an explanation of its significance in the context of pollution:\n\n### 1. A Global Benchmark for Poor Air Quality\nDuring the winter months (especially between October and January), Delhi routinely tops global air quality indexes (AQI), with pollution levels often reaching "Severe" or "Hazardous" categories—sometimes exceeding **500 to 1,000 AQI**, which is dozens of times higher than the World Health Organization\'s (WHO) safe limits. This has made Delhi a primary global case study for urban air pollution and public health crises.\n\n### 2. The Multi-Factor Pollution Crisis\nDelhi\'s significance in pollution lies in the complex combination of geographic, meteorological, and human-made factors that trap pollutants in the atmosphere:\n* **Stubble Burning:** After the harvest season in the neighboring agricultural states of Punjab and Haryana, farmers burn crop residue (stubble). Winds carry this massive plume of smoke directly into the Delhi basin.\n* **Vehicular Emissions:** As a massive urban center with millions of registered vehicles, traffic congestion contributes heavily to nitrogen dioxide ($\\text{NO}_2$) and particulate matter ($\\text{PM}_{2.5}$ and $\\text{PM}_{10}$).\n* **Industrial Pollution and Construction:** Unregulated industrial units surrounding the city and massive, dust-generating construction projects constantly pump pollutants into the air.\n* **Geography and Weather:** In winter, a phenomenon called **temperature inversion** occurs. Cold air traps a layer of warmer air underneath it, acting like a lid that prevents pollutants from rising and dispersing. Combined with low wind speeds, the city effectively becomes a giant gas chamber.\n* **Festivals:** The burning of firecrackers during Diwali (usually coinciding with the onset of winter) drastically spikes air pollution over a very short period.\n\n### 3. Public Health and Economic Impact\nThe pollution crisis in Delhi is significant because of its devastating toll on human life and productivity:\n* **Health Crisis:** Doctors in Delhi frequently declare a public health emergency. Millions of residents suffer from chronic bronchitis, asthma, lung damage, and reduced life expectancy. Studies suggest that severe air pollution shaves years off the lives of Delhi\'s citizens.\n* **Economic Toll:** Productivity drops due to illness, school closures, and reduced outdoor activity. The government frequently has to halt construction work and restrict vehicle use (such as the "Odd-Even" car rationing scheme), disrupting economic activity.\n\n### 4. A Testing Ground for Environmental Policy\nBecause Delhi is the national capital, it sits at the epicenter of India\'s legal and political battles over climate change. \n* **The Judiciary:** The Supreme Court of India and the National Green Tribunal (NGT) frequently intervene, issuing strict mandates on fuel standards (e.g., jumping straight to Bharat Stage VI fuel), banning older diesel and petrol vehicles, and penalizing state governments for failing to curb stubble burning.\n* **Technological Interventions:** Delhi has experimented with various high-profile measures, including anti-smog towers, water-sprinkling trucks, and smog guns, though their long-term effectiveness remains debated.\n\n### Summary\nIn the context of pollution, New Delhi is significant not only as a tragic symbol of the friction between rapid urbanization and environmental degradation, but also as a warning sign for other megacities in the developing world. It forces policymakers to grapple with the existential challenge  ...
