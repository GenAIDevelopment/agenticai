# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
def print_response(response):
    for block in response.content_blocks:
        if block['type'] == 'text':
            print(block['text'])

# %% [markdown]
# ## Zero shot prompting

# %%
response = llm.invoke("What is inertia?")
print_response(response)
# Out:
# In physics, **inertia** is the tendency of an object to resist changes in its state of motion.
#
# The concept was famously defined by Sir Isaac Newton in his **First Law of Motion**, often called the "Law of Inertia," which states:
#
# > *An object at rest will stay at rest, and an object in motion will stay in motion with the same speed and in the same direction unless acted upon by an unbalanced force.*
#
# Here is a breakdown of what that actually means:
#
# ### 1. It is about "Laziness"
# You can think of inertia as an object's "laziness." Matter does not want to change what it is doing.
# *   If an object is **sitting still**, it wants to keep sitting still. It won't start moving unless something (a force) pushes or pulls it.
# *   If an object is **already moving**, it wants to keep moving at the same speed and in the same direction forever. It won't stop, speed up, or turn unless something forces it to.
#
# ### 2. Inertia and Mass
# The amount of inertia an object has depends entirely on its **mass**.
# *   **Mass is a measure of inertia.**
# *   The more mass an object has, the more "lazy" it is—meaning it is harder to move or harder to stop.
# *   **Example:** It is much easier to push a skateboard (low mass) than it is to push a semi-truck (high mass). The truck has more inertia, so it resists changes to its motion much more strongly.
#
# ### 3. Real-World Examples
# You experience inertia every day:
#
# *   **The Car Seat:** If you are riding in a car and the driver slams on the brakes, your body jerks forward. Your body was moving at the speed of the car, and your inertia wants to *keep* moving at that speed, even though the car has stopped.
# *   **The Tablecloth Trick:** If you pull a tablecloth out from under dishes very quickly, the dishes stay put. They have inertia—they "want" to stay at rest, and because the pull is so fast, the friction isn't enough to overcome their inertia and move them along with the cloth.
# *   **Space Travel:** This is why space probes can travel through the vacuum of space for years without using fuel. Once they are moving, there is no air resistance or friction to slow them down, so their inertia keeps them moving in a straight line indefinitely.
#
# ### Why doesn't everything stay in motion forever on Earth?
# You might wonder, "If things want to keep moving, why does a soccer ball stop rolling after I kick it?"
#
# The ball stops because of **external forces**—specifically **friction** with the grass and **air resistance**. If you were in the vacuum of space, that ball would technically continue moving in a straight line forever because there would be no forces to change its motion.

# %% [markdown]
# ## Few shot prompts

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage

# %%
messages = [
    HumanMessage("what is 2 * 2 + 3 ?"),
    AIMessage("""
    step 1: 2 * 2 = 4
    step 2: 4 + 3 = 7

    Answer: 7
    """),
    HumanMessage("What is 3 - 3 + 6 + 4 ?"),
    AIMessage("""
    step 1: 3 - 3 = 0
    step 2: 0 + 6 = 6
    step 3: 6 + 4 = 10

    Answer: 10
    """),
    HumanMessage("what is 5 * 6 - 2 ?")
    
]

# %%
response = llm.invoke(messages)
print_response(response)
# Out:
# step 1: 5 * 6 = 30
# step 2: 30 - 2 = 28
#
# Answer: 28

# %% [markdown]
# ## Creating models just by passing a string
#
# * Convention `provider:model`

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()
# approach 1
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite"
)

response = model.invoke("What is capital of France?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAERTTIPWwdQC5v6Cfqrqdfkp1N+iRs7SRuY2Lb1sgkh/7Zl3Jnvq+/EEBao1DYEX8LqSvwMnfa7USftmmgRdT3F+K+0LEVFOuyaVfUqZJX8lCM9NAg5t8ZApNeX'}}]

# %%
# approach 2

model = init_chat_model(
    model="gemini-3.5-flash-lite",
    model_provider="google_genai"
)
response = model.invoke("What is capital of France?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAERTTIPxsw222x4OcibmTup8BSxzY1cBhVOF1/a+FEVQ2Yoet8xd1x2jP4xvTKlsQhiFTMSmNwe8/Bv008mM/pZEUfpmuQbCcog/XO8Yg1w+2u7baRzWNOoLKwm'}}]

# %%
# approach 3
model = init_chat_model(model="google_genai:gemini-3.5-flash-lite")
response = model.invoke("What is capital of France?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAERTTIPifzBzpEpKy1fBBL7O64ZrLh/lEsMjTekq13huJQ5kcskWeApvwfqF9Ig/qclajAa/ObAaNM7MP865ukpVWn2ipih1Ug98BO0UncmDAypi6DGw+mgTJdd'}}]

# %%
# creating agent
from langchain.agents import create_agent
# approach 1
# create model
model = init_chat_model(model="google_genai:gemini-3.5-flash-lite")
agent = create_agent(
    model=model,
    tools = []
)
response = agent.invoke({
    "messages": ["What is capital of france"]
})
for message in response['messages']:
    print(message)
# Out:
# content='What is capital of france' additional_kwargs={} response_metadata={} id='c01effd6-f8d4-4751-a244-660427b874d7'
# content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'El4KXAERTTIPOA8GrmWAuoJC6Cbou6IJ+m93YIulApDu5dj1HjT5KMQ2hQv7UF4ugSQkVs3sEIRr1RoWGEodICrJPHEqR4zNM6O8iVyRma8P66bfvVXM71jQYoHbKEFm'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0600c-bad1-75a2-9fff-e0eb27d023b7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}}

# %%
# approach 2
agent = create_agent(
    model="google_genai:gemini-3.1-flash-lite",
    tools = []
)
response = agent.invoke({
    "messages": ["What is capital of france"]
})
for message in response['messages']:
    print(message)
# Out:
# content='What is capital of france' additional_kwargs={} response_metadata={} id='9494c7f8-ce29-4316-9d2e-e08d3e5cbe41'
# content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIPyLVb6HLmQyQe64ouS66mIS6Vs67LY1M1nNwesLJQLaoPvVNqI/AMGHcuvgBajpBiG4gtwOUQhJ2s/ojQ6N67WURW7ak5KCZYC2ru/SfvApF8fYBTY6lVydsXZYzuWToUH9+YlPQh/mTuIg=='}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0600c-c6b6-7130-ad1c-49c0671bbf67-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}}

# %%
model = init_chat_model("openrouter:openrouter/free")
response = model.invoke("What is capital of France?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of France is **Paris**.

# %%
model_name="z-ai/glm-5.2:free"
model_provider="openrouter"
model = init_chat_model(f"{model_provider}:{model_name}")
response = model.invoke("What is capital of France?")
response.pretty_print()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsResponseError              Traceback (most recent call last)
# Cell In[21], line 4
#       1 model_name="z-ai/glm-5.2:free"
#       2 model_provider="openrouter"
#       3 model = init_chat_model(f"{model_provider}:{model_name}")
# ----> 4 response = model.invoke("What is capital of France?")
#       5 response.pretty_print()
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:477, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     463 @override
#     464 def invoke(
#     465     self,
#    (...)    470     **kwargs: Any,
#     471 ) -> AIMessage:
#     472     config = ensure_config(config)
#     473     return cast(
#     474         "AIMessage",
#     475         cast(
#     476             "ChatGeneration",
# --> 477             self.generate_prompt(
#     478                 [self._convert_input(input)],
#     479                 stop=stop,
#     480                 callbacks=config.get("callbacks"),
#     481                 tags=config.get("tags"),
#     482                 metadata=config.get("metadata"),
#     483                 run_name=config.get("run_name"),
#     484                 run_id=config.pop("run_id", None),
#     485                 **kwargs,
#     486             ).generations[0][0],
#     487         ).message,
#     488     )
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1866, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1857 @override
#    1858 def generate_prompt(
#    1859     self,
#    (...)   1863     **kwargs: Any,
#    1864 ) -> LLMResult:
#    1865     prompt_messages = [p.to_messages() for p in prompts]
# -> 1866     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1673, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1670 for i, m in enumerate(input_messages):
#    1671     try:
#    1672         results.append(
# -> 1673             self._generate_with_cache(
#    1674                 m,
#    1675                 stop=stop,
#    1676                 run_manager=run_managers[i] if run_managers else None,
#    1677                 **kwargs,
#    1678             )
#    1679         )
#    1680     except BaseException as e:
#    1681         if run_managers:
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2009     result = generate_from_stream(iter(chunks))
#    2010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2011     result = self._generate(
#    2012         messages, stop=stop, run_manager=run_manager, **kwargs
#    2013     )
#    2014 else:
#    2015     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\langchain_openrouter\chat_models.py:572, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     570 params = {**params, **kwargs}
#     571 _strip_internal_kwargs(params)
# --> 572 response = self.client.chat.send(messages=message_dicts, **params)
#     573 return self._create_chat_result(response)
#
# File c:\khajaclassroom\GenerativeAI\agenticai\aug26\basic-agents\hello_llm\.venv\Lib\site-packages\openrouter\chat.py:926, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, x_open_router_metadata, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, min_p, modalities, model, models, parallel_tool_calls, plugins, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, provider, reasoning, reasoning_effort, repetition_penalty, response_format, seed, service_tier, session_id, stop, stop_server_tools_when, stream, stream_options, temperature, tool_choice, tools, top_a, top_k, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     922     http_res_text = utils.stream_to_text(http_res)
#     923     response_data = unmarshal_json_response(
#     924         errors.TooManyRequestsResponseErrorData, http_res, http_res_text
#     925     )
# --> 926     raise errors.TooManyRequestsResponseError(
#     927         response_data, http_res, http_res_text
#     928     )
#     929 if utils.match_response(http_res, "500", "application/json"):
#     930     http_res_text = utils.stream_to_text(http_res)
#
# TooManyRequestsResponseError: Provider returned error

# %%
def print_agent_response(response):
    for message in response['messages']:
        print(message)

# %%
agent_without_shortterm_memory = create_agent(
    model='google_genai:gemini-3.5-flash-lite'
)

response = agent_without_shortterm_memory.invoke(
    {
        "messages": "My name is khaja"
    }
)
print_agent_response(response)

response = agent_without_shortterm_memory.invoke(
    {
        "messages": "What is my name?"
    }
)
print_agent_response(response)
# Out:
# content='My name is khaja' additional_kwargs={} response_metadata={} id='1fed508d-97bb-4cac-a682-c0302df29686'
# content=[{'type': 'text', 'text': 'Nice to meet you, Khaja! How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPl4/KigqtJby6wY/bEBPkEj+hnx+Kaq0p3GRcyZUpb7vHPSQdp5Qo0qVb1jQWcDKh1wZUTKYIMEAIunfRrCPTOLlzDp2xisFRfaBxwpJrBqM8vGeAOJhv'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a06026-bd1a-7e50-8bcb-c7dd29966124-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 15, 'total_tokens': 21, 'input_token_details': {'cache_read': 0}}
# content='What is my name?' additional_kwargs={} response_metadata={} id='cf8da506-e2c6-4256-ab15-c8a3d0e8b111'
# content=[{'type': 'text', 'text': "I don't know your name! You haven't told me yet. What should I call you?", 'extras': {'signature': 'El4KXAERTTIPd/NOkePNjBp94k+U5DdXfTIL6UIVhEU1ESCoaKaxaXLWKQ2Jqie/vf5eL2wHojKo1pfQVqGQiY4bZSAR7hTvKYhNM8eo3i9OY6d4Qov6lOwRMN1Gt63m'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a06026-c0e5-75f1-ac05-c70816c82e17-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 22, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}}

# %%
from langgraph.checkpoint.memory import InMemorySaver
cfg_1 = {"configurable": {"thread_id": "classroom-02sep"}}
cfg_2 = {"configurable": {"thread_id": "klsdjfdaslk"}}

agent_with_shortterm_memory = create_agent(
    model='google_genai:gemini-3.5-flash-lite',
    checkpointer=InMemorySaver(),
)

response = agent_with_shortterm_memory.invoke(
    {
        "messages": "My name is khaja"
    },
    cfg_1
)
print_agent_response(response)
# Out:
# content='My name is khaja' additional_kwargs={} response_metadata={} id='ddfd7539-7883-4dd9-9d8d-905b58355fe4'
# content=[{'type': 'text', 'text': 'Hello Khaja! Nice to meet you. How can I help you today?', 'extras': {'signature': 'El4KXAERTTIP/0Td678cZO1fZzTUo17PYVoOskhPx0Wy0sS95TSSRhxZAhtylX1vAcWzQdThu5nMrlkluRxr9nldUa3vR/uGrVg5BDAvMmLpgybiauPbG4tmoOzoA1uC'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0602d-a833-7c73-889a-0a2680599580-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 16, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}

# %%
# agent with short term same thread/conversation
response = agent_with_shortterm_memory.invoke(
    {
        "messages": "What is my name?"
    },
    cfg_1
)
print_agent_response(response)
# Out:
# content='My name is khaja' additional_kwargs={} response_metadata={} id='ddfd7539-7883-4dd9-9d8d-905b58355fe4'
# content=[{'type': 'text', 'text': 'Hello Khaja! Nice to meet you. How can I help you today?', 'extras': {'signature': 'El4KXAERTTIP/0Td678cZO1fZzTUo17PYVoOskhPx0Wy0sS95TSSRhxZAhtylX1vAcWzQdThu5nMrlkluRxr9nldUa3vR/uGrVg5BDAvMmLpgybiauPbG4tmoOzoA1uC'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0602d-a833-7c73-889a-0a2680599580-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 16, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}
# content='What is my name?' additional_kwargs={} response_metadata={} id='efe6676f-251c-40b6-b888-dd9c83ad72e4'
# content=[{'type': 'text', 'text': 'Your name is Khaja!', 'extras': {'signature': 'El4KXAERTTIP8oeFkRsuwmMehSSzO2q4n6rFgmZF3Wcbk3TMMD6pF+HA09O/Q6OodbBFKJq7S2wf3HtFmh1jF2DbT5fMoEZnje2HpG26JiC4+hmVOMpHMwy4orbxpdi7'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0602d-e703-7c82-b431-8d9dc48583db-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 29, 'output_tokens': 6, 'total_tokens': 35, 'input_token_details': {'cache_read': 0}}

# %%
# agent with short term different thread/conversation
response = agent_with_shortterm_memory.invoke(
    {
        "messages": "What is my name?"
    },
    cfg_2
)
print_agent_response(response)
# Out:
# content='What is my name?' additional_kwargs={} response_metadata={} id='ea1d72e3-d286-4221-8e81-cee02df860cf'
# content=[{'type': 'text', 'text': "I don't know your name because you haven't told me yet! What should I call you?", 'extras': {'signature': 'El4KXAERTTIPFlg2YXhOv8NYg40RjBP72iB9zNKmLzytPnufERerlbhH4kd6NKLM9yGEzFC0nr9pGTR2zk4abSsuf0m1Hcj7t8GtMbnRT87Ra3cfaymsKhkyNb3NkGCG'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0602e-1646-7993-b273-a35a17b0b2b8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 22, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}}
