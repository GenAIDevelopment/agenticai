# %% [markdown]
# ## Typed Dict

# %%
# normal dictionary
student_info = {
    'name': 'qt',
    'age': 17,
    'email': 'qt@gmail.com'
}

# %%
from typing import TypedDict

class StudentInfo(TypedDict):
    name: str
    age: int
    email: str

# %%
x = StudentInfo(name='qt', age=17, email='qt@gmail.com')

# %%
x
# Out:
# {'name': 'qt', 'age': 17, 'email': 'qt@gmail.com'}

# %%
from dataclasses import dataclass

# %% [markdown]
# ### Message passing options

# %%
from conditional_demo import graph

graph
